# %%
from dotenv import load_dotenv

load_dotenv()

stopwords = [
    "진짜",
    "정말",
    "영상",
    "채널",
    "구독",
    "좋아요",
    "댓글",
    "보고",
    "수",
    "거",
    "나",
]

# %%
# https://www.youtube.com/watch?v=PfseJBL9Vl0

import lib.visualization as visual
from lib.youtube import collect_all_comments

rows, texts = collect_all_comments("PfseJBL9Vl0", include_replies=True)
print(len(rows), len(texts))

# visual.word_cloud(texts, stopwords=stopwords)

# %%
# https://www.youtube.com/watch?v=ZghVVrcYAuc

import lib.youtube as yt

rows, texts = yt.collect_all_comments("ZghVVrcYAuc")

visual.word_cloud(texts, stopwords=stopwords)

# %%
# https://www.youtube.com/watch?v=wu_2Lganvp4

import lib.visualization as visual
import lib.youtube as yt

rows, texts = yt.collect_all_comments("FVFRVGSvkq0")

# %%
visual.word_cloud(texts, stopwords=stopwords, mask_img_path="../../images/circle.png")

# %%
# https://www.youtube.com/shorts/BsHQOOlg6Bs

import lib.visualization as visual
from lib.youtube import collect_all_comments

rows, texts = collect_all_comments("BsHQOOlg6Bs")
print(len(rows), len(texts))

# %%
visual.word_cloud(texts, stopwords=stopwords, mask_img_path="../../images/map.jpg")

# %%
from lib.util import collect_comments

data = collect_comments("BsHQOOlg6Bs")
print(data)
