# %%
import pandas as pd
import requests

apiKey = "ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M"

base_url = "https://kosis.kr/openapi/Param/statisticsParameterData.do"
# https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M=&itmId=T001+&objL1=33+33020+33030+33040+33520+33530+34+34010+34020+34030+34040+&objL2=ALL&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1YL20642

method = "getList"
apiKey = "ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M="
itmId = "T001+"
objL1 = "00+11+21+22+23+24+25+26+29+31+32+33+34+35+36+37+38+39+"
objL2 = "ALL"
objL3 = ""
objL4 = ""
objL5 = ""
objL6 = ""
objL7 = ""
objL8 = ""
format = "json"
jsonVD = "Y"
prdSe = "Y"
newEstPrdCnt = "3"
orgId = "101"
tblId = "DT_1YL20642"



url = f"{base_url}?method=getList&apiKey=ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M=&itmId=T001+&objL1=00+11+21+22+23+24+25+26+29+31+32+33+34+35+36+37+38+39+&objL2=ALL&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1YL20642"

response = requests.get(url)

items = response.json()
items

# %%
df = pd.DataFrame(items)
df.set_index(list(df)[0])


# df.to_csv("./data/청년순이동률.csv")

df
