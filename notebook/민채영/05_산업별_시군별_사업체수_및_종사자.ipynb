# %%
from dotenv import load_dotenv
import requests 
import pandas as pd

base_url = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M=&itmId=T001+T002+T003+T004+T005+&objL1=ALL&objL2=ALL&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=210&tblId=DT_21002D003"

response = requests.get(base_url)

items = response.json()
items
# Out:
# [{'C1_OBJ_NM': '시군별',
#   'C2_NM': '합계',
#   'DT': '1481054',
#   'C2': '001',
#   'C1': '001',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Number',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_21002D003',
#   'ITM_NM': '사업체수',
#   'TBL_NM': '산업별 시군별 사업체수 및 종사자수',
#   'PRD_DE': '2021',
#   'LST_CHN_DE': '2023-05-15',
#   'C1_NM_ENG': 'Gyeonggi-do',
#   'C1_NM': '합계',
#   'UNIT_NM': '개',
#   'ITM_NM_ENG': 'Estab',
#   'C2_OBJ_NM_ENG': 'By Industry',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '210',
#   'C1_OBJ_NM_ENG': 'By Si Gun',
#   'C2_OBJ_NM': '산업별'},
#  {'C1_OBJ_NM': '시군별',
#   'C2_NM': '합계',
#   'DT': '1514951',
#   'C2': '001',
#   'C1': '001',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Number',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_21002D003',
#   'ITM_NM': '사업체수',
#   'TBL_NM': '산업별 시군별 사업체수 및 종사자수',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-04-23',
#   'C1_NM_ENG': 'Gyeonggi-do',
#   'C1_NM': '합계',
#   'UNIT_NM': '개',
#   'ITM_NM_ENG': 'Estab',
#   'C2_OBJ_NM_ENG': 'By Industry',
# ...

# %%
df = pd.DataFrame(items)
df
# Out:
#      C1_OBJ_NM                    C2_NM       DT   C2      C1 PRD_SE  \
# 0          시군별                       합계  1481054  001     001      A
# 1          시군별                       합계  1514951  001     001      A
# 2          시군별                       합계  1562116  001     001      A
# 3          시군별                       합계   529270  001     001      A
# 4          시군별                       합계   541981  001     001      A
# ...        ...                      ...      ...  ...     ...    ...
# 4381       시군별  협회 및 단체 수리 및 기타 개인 서비스업    29249  020  001039      A
# 4382       시군별  협회 및 단체 수리 및 기타 개인 서비스업    30657  020  001039      A
# 4383       시군별  협회 및 단체 수리 및 기타 개인 서비스업    52642  020  001039      A
# 4384       시군별  협회 및 단체 수리 및 기타 개인 서비스업    53534  020  001039      A
# 4385       시군별  협회 및 단체 수리 및 기타 개인 서비스업    54964  020  001039      A
#
#      UNIT_NM_ENG ITM_ID        TBL_ID      ITM_NM  ...  LST_CHN_DE  \
# 0         Number   T001  DT_21002D003        사업체수  ...  2023-05-15
# ...
