# %%
from dotenv import load_dotenv
import requests 
import pandas as pd

base_url = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M=&itmId=T00+T11+T12+T21+&objL1=ALL&objL2=ALL&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=H&newEstPrdCnt=3&orgId=101&tblId=DT_1ES3A03_A01S"

response = requests.get(base_url)

items = response.json()
items
# Out:
# [{'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '계',
#   'DT': '72.5',
#   'C2': '000',
#   'C1': '1101',
#   'PRD_SE': 'S',
#   'UNIT_NM_ENG': 'Thousand Person               ',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1ES3A03_A01S',
#   'ITM_NM': '취업자 (천명)',
#   'TBL_NM': '시군구/연령별 취업자 및 고용률 (전체)',
#   'PRD_DE': '202401',
#   'LST_CHN_DE': '2024-08-02',
#   'C1_NM_ENG': 'Jongno-gu',
#   'C1_NM': '서울 종로구',
#   'UNIT_NM': '천명',
#   'ITM_NM_ENG': 'Employed persons (In thousand persons)',
#   'C2_OBJ_NM_ENG': 'By age group',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '계',
#   'DT': '72.9',
#   'C2': '000',
#   'C1': '1101',
#   'PRD_SE': 'S',
#   'UNIT_NM_ENG': 'Thousand Person               ',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1ES3A03_A01S',
#   'ITM_NM': '취업자 (천명)',
#   'TBL_NM': '시군구/연령별 취업자 및 고용률 (전체)',
#   'PRD_DE': '202402',
#   'LST_CHN_DE': '2025-02-04',
# ...

# %%
df = pd.DataFrame(items)
df
# Out:
#      C1_OBJ_NM     C2_NM    DT   C2    C1 PRD_SE  \
# 0        행정구역별         계  72.5  000  1101      S
# 1        행정구역별         계  72.9  000  1101      S
# 2        행정구역별         계  70.8  000  1101      S
# 3        행정구역별         계  53.5  000  1101      S
# 4        행정구역별         계  53.8  000  1101      S
# ...        ...       ...   ...  ...   ...    ...
# 9711     행정구역별  15 - 64세  85.9  060  3902      S
# 9712     행정구역별  15 - 64세  85.6  060  3902      S
# 9713     행정구역별  15 - 64세  76.8  060  3902      S
# 9714     행정구역별  15 - 64세  75.4  060  3902      S
# 9715     행정구역별  15 - 64세  75.9  060  3902      S
#
#                          UNIT_NM_ENG ITM_ID           TBL_ID    ITM_NM  ...  \
# 0     Thousand Person                   T00  DT_1ES3A03_A01S  취업자 (천명)  ...
# 1     Thousand Person                   T00  DT_1ES3A03_A01S  취업자 (천명)  ...
# 2     Thousand Person                   T00  DT_1ES3A03_A01S  취업자 (천명)  ...
# ...
