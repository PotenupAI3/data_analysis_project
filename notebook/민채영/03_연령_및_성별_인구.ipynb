# %%
from dotenv import load_dotenv
import requests 
import pandas as pd

base_url = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M=&itmId=T00+T10+T20+T30+&objL1=00+04+05+03+11+21+22+23+24+25+26+29+31+32+33+34+35+36+37+38+39+&objL2=000+005+010+015+020+025+030+035+040+045+050+055+060+065+070+075+080+085+086+090+095+100+101+999+102+103+104+126+127+&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1IN1603"

response = requests.get(base_url)

items = response.json()
items
# Out:
# [{'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '49855796',
#   'C2': '000',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '24881520',
#   'C2': '000',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '24974276',
#   'C2': '000',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '99.6',
#   'C2': '000',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '2192603',
#   'C2': '005',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '1124012',
#   'C2': '005',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '1068591',
#   'C2': '005',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '105.2',
#   'C2': '005',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '5~9세',
#   'DT': '2287123',
#   'C2': '010',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '5 to 9 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '5~9세',
#   'DT': '1177879',
#   'C2': '010',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '5 to 9 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '5~9세',
#   'DT': '1109244',
#   'C2': '010',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '5 to 9 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '5~9세',
#   'DT': '106.2',
#   'C2': '010',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '5 to 9 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '10~14세',
#   'DT': '2288612',
#   'C2': '015',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '10 to 14 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '10~14세',
#   'DT': '1188475',
#   'C2': '015',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '10 to 14 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '10~14세',
#   'DT': '1100137',
#   'C2': '015',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '10 to 14 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '10~14세',
#   'DT': '108',
#   'C2': '015',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '10 to 14 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~19세',
#   'DT': '3056728',
#   'C2': '020',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 19 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~19세',
#   'DT': '1594229',
#   'C2': '020',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 19 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~19세',
#   'DT': '1462499',
#   'C2': '020',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 19 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~19세',
#   'DT': '109',
#   'C2': '020',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 19 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '20~24세',
#   'DT': '3400634',
#   'C2': '025',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '20 to 24 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '20~24세',
#   'DT': '1816165',
#   'C2': '025',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '20 to 24 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '20~24세',
#   'DT': '1584469',
#   'C2': '025',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '20 to 24 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '20~24세',
#   'DT': '114.6',
#   'C2': '025',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '20 to 24 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '25~29세',
#   'DT': '3068970',
#   'C2': '030',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '25 to 29 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '25~29세',
#   'DT': '1607473',
#   'C2': '030',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '25 to 29 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '25~29세',
#   'DT': '1461497',
#   'C2': '030',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '25 to 29 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '25~29세',
#   'DT': '110',
#   'C2': '030',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '25 to 29 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '30~34세',
#   'DT': '3415599',
#   'C2': '035',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '30 to 34 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '30~34세',
#   'DT': '1756053',
#   'C2': '035',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '30 to 34 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '30~34세',
#   'DT': '1659546',
#   'C2': '035',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '30 to 34 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '30~34세',
#   'DT': '105.8',
#   'C2': '035',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '30 to 34 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '35~39세',
#   'DT': '3852007',
#   'C2': '040',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '35 to 39 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '35~39세',
#   'DT': '1963865',
#   'C2': '040',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '35 to 39 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '35~39세',
#   'DT': '1888142',
#   'C2': '040',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '35 to 39 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '35~39세',
#   'DT': '104',
#   'C2': '040',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '35 to 39 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '40~44세',
#   'DT': '4031799',
#   'C2': '045',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '40 to 44 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '40~44세',
#   'DT': '2049032',
#   'C2': '045',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '40 to 44 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '40~44세',
#   'DT': '1982767',
#   'C2': '045',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '40 to 44 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '40~44세',
#   'DT': '103.3',
#   'C2': '045',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '40 to 44 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '45~49세',
#   'DT': '4369603',
#   'C2': '050',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '45 to 49 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '45~49세',
#   'DT': '2196126',
#   'C2': '050',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '45 to 49 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '45~49세',
#   'DT': '2173477',
#   'C2': '050',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '45 to 49 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '45~49세',
#   'DT': '101',
#   'C2': '050',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '45 to 49 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '50~54세',
#   'DT': '4030564',
#   'C2': '055',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '50 to 54 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '50~54세',
#   'DT': '2045888',
#   'C2': '055',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '50 to 54 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '50~54세',
#   'DT': '1984676',
#   'C2': '055',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '50 to 54 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '50~54세',
#   'DT': '103.1',
#   'C2': '055',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '50 to 54 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '55~59세',
#   'DT': '4076050',
#   'C2': '060',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '55 to 59 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '55~59세',
#   'DT': '2025701',
#   'C2': '060',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '55 to 59 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '55~59세',
#   'DT': '2050349',
#   'C2': '060',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '55 to 59 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '55~59세',
#   'DT': '98.8',
#   'C2': '060',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '55 to 59 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '60~64세',
#   'DT': '3010386',
#   'C2': '065',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '60 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '60~64세',
#   'DT': '1473557',
#   'C2': '065',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '60 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '60~64세',
#   'DT': '1536829',
#   'C2': '065',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '60 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '60~64세',
#   'DT': '95.9',
#   'C2': '065',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '60 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65~69세',
#   'DT': '2179524',
#   'C2': '070',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 to 69 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65~69세',
#   'DT': '1044970',
#   'C2': '070',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 to 69 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65~69세',
#   'DT': '1134554',
#   'C2': '070',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 to 69 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65~69세',
#   'DT': '92.1',
#   'C2': '070',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 to 69 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '70~74세',
#   'DT': '1736294',
#   'C2': '075',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '70 to 74 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '70~74세',
#   'DT': '786401',
#   'C2': '075',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '70 to 74 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '70~74세',
#   'DT': '949893',
#   'C2': '075',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '70 to 74 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '70~74세',
#   'DT': '82.8',
#   'C2': '075',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '70 to 74 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '75~79세',
#   'DT': '1418480',
#   'C2': '080',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '75 to 79 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '75~79세',
#   'DT': '583304',
#   'C2': '080',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '75 to 79 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '75~79세',
#   'DT': '835176',
#   'C2': '080',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '75 to 79 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '75~79세',
#   'DT': '69.8',
#   'C2': '080',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '75 to 79 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '80~84세',
#   'DT': '880699',
#   'C2': '085',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '80 to 84 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '80~84세',
#   'DT': '306320',
#   'C2': '085',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '80 to 84 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '80~84세',
#   'DT': '574379',
#   'C2': '085',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '80 to 84 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '80~84세',
#   'DT': '53.3',
#   'C2': '085',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '80 to 84 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85세 이상',
#   'DT': '560121',
#   'C2': '086',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85세 이상',
#   'DT': '142070',
#   'C2': '086',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85세 이상',
#   'DT': '418051',
#   'C2': '086',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85세 이상',
#   'DT': '34',
#   'C2': '086',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85~89세',
#   'DT': '398827',
#   'C2': '090',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 to 89 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85~89세',
#   'DT': '106818',
#   'C2': '090',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 to 89 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85~89세',
#   'DT': '292009',
#   'C2': '090',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 to 89 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '85~89세',
#   'DT': '36.6',
#   'C2': '090',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '85 to 89 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '90~94세',
#   'DT': '130010',
#   'C2': '095',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '90 to 94 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '90~94세',
#   'DT': '29346',
#   'C2': '095',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '90 to 94 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '90~94세',
#   'DT': '100664',
#   'C2': '095',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '90 to 94 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '90~94세',
#   'DT': '29.2',
#   'C2': '095',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '90 to 94 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '95~99세',
#   'DT': '27798',
#   'C2': '100',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '95 to 99 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '95~99세',
#   'DT': '5461',
#   'C2': '100',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '95 to 99 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '95~99세',
#   'DT': '22337',
#   'C2': '100',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '95 to 99 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '95~99세',
#   'DT': '24.4',
#   'C2': '100',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '95 to 99 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '100세이상',
#   'DT': '3486',
#   'C2': '101',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '100 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '100세이상',
#   'DT': '445',
#   'C2': '101',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '100 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '100세이상',
#   'DT': '3041',
#   'C2': '101',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Whole country',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '100 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '100세이상',
# ...
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '100 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '100세이상',
#   'DT': '87',
#   'C2': '101',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '100 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '100세이상',
#   'DT': '6.9',
#   'C2': '101',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '100 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15세미만',
#   'DT': '218936',
#   'C2': '102',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Under 15 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15세미만',
#   'DT': '113329',
#   'C2': '102',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Under 15 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15세미만',
#   'DT': '105607',
#   'C2': '102',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Under 15 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15세미만',
#   'DT': '107.3',
#   'C2': '102',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Under 15 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~64세',
#   'DT': '1084404',
#   'C2': '103',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~64세',
#   'DT': '547290',
#   'C2': '103',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~64세',
#   'DT': '537114',
#   'C2': '103',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '15~64세',
#   'DT': '101.9',
#   'C2': '103',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '15 to 64 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65세이상',
#   'DT': '174516',
#   'C2': '104',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65세이상',
#   'DT': '73473',
#   'C2': '104',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65세이상',
#   'DT': '101043',
#   'C2': '104',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '65세이상',
#   'DT': '72.7',
#   'C2': '104',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '65 years and over',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '평균연령',
#   'DT': '39.1',
#   'C2': '126',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Mean ages',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '평균연령',
#   'DT': '38',
#   'C2': '126',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Mean ages',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '평균연령',
#   'DT': '40.2',
#   'C2': '126',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Mean ages',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '중위연령',
#   'DT': '39.7',
#   'C2': '127',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Median ages',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '중위연령',
#   'DT': '38.6',
#   'C2': '127',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Median ages',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '중위연령',
#   'DT': '40.8',
#   'C2': '127',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Gwangju',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Median ages',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '1515758',
#   'C2': '000',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '761749',
#   'C2': '000',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '754009',
#   'C2': '000',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '합계',
#   'DT': '101',
#   'C2': '000',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': 'Total',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '68220',
#   'C2': '005',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '35246',
#   'C2': '005',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '32974',
#   'C2': '005',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T20',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '여자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Female',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '0~4세',
#   'DT': '106.9',
#   'C2': '005',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'ITM_ID': 'T30',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '성비',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'ITM_NM_ENG': 'Sex ratio',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '0 to 4 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '5~9세',
#   'DT': '72474',
#   'C2': '010',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T00',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '인구(내국인)',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Population(Korean)',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '5 to 9 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  {'C1_OBJ_NM': '행정구역별(시군구)',
#   'C2_NM': '5~9세',
#   'DT': '37283',
#   'C2': '010',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'Person',
#   'ITM_ID': 'T10',
#   'TBL_ID': 'DT_1IN1603',
#   'ITM_NM': '남자',
#   'TBL_NM': '연령 및 성별 인구 - 시군구',
#   'PRD_DE': '2016',
#   'LST_CHN_DE': '2017-08-30',
#   'C1_NM_ENG': 'Daejeon',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ITM_NM_ENG': 'Male',
#   'C2_OBJ_NM_ENG': 'By age ',
#   'C2_NM_ENG': '5 to 9 years',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'By administrative divisions',
#   'C2_OBJ_NM': '연령별'},
#  ...]

# %%
df = pd.DataFrame(items)
df
# Out:
#        C1_OBJ_NM C2_NM        DT   C2  C1 PRD_SE UNIT_NM_ENG ITM_ID  \
# 0     행정구역별(시군구)    합계  49855796  000  00      A      Person    T00
# 1     행정구역별(시군구)    합계  24881520  000  00      A      Person    T10
# 2     행정구역별(시군구)    합계  24974276  000  00      A      Person    T20
# 3     행정구역별(시군구)    합계      99.6  000  00      A         NaN    T30
# 4     행정구역별(시군구)  0~4세   2192603  005  00      A      Person    T00
# ...          ...   ...       ...  ...  ..    ...         ...    ...
# 2305  행정구역별(시군구)  평균연령      39.1  126  39      A      Person    T10
# 2306  행정구역별(시군구)  평균연령        42  126  39      A      Person    T20
# 2307  행정구역별(시군구)  중위연령      41.9  127  39      A      Person    T00
# 2308  행정구역별(시군구)  중위연령      40.8  127  39      A      Person    T10
# 2309  행정구역별(시군구)  중위연령        43  127  39      A      Person    T20
#
#           TBL_ID   ITM_NM  ...  LST_CHN_DE      C1_NM_ENG    C1_NM UNIT_NM  \
# 0     DT_1IN1603  인구(내국인)  ...  2017-08-30  Whole country       전국       명
# 1     DT_1IN1603       남자  ...  2017-08-30  Whole country       전국       명
# 2     DT_1IN1603       여자  ...  2017-08-30  Whole country       전국       명
# 3     DT_1IN1603       성비  ...  2017-08-30  Whole country       전국     NaN
# 4     DT_1IN1603  인구(내국인)  ...  2017-08-30  Whole country       전국       명
# ...          ...      ...  ...         ...            ...      ...     ...
# 2305  DT_1IN1603       남자  ...  2017-08-30           Jeju  제주특별자치도       명
# 2306  DT_1IN1603       여자  ...  2017-08-30           Jeju  제주특별자치도       명
# 2307  DT_1IN1603  인구(내국인)  ...  2017-08-30           Jeju  제주특별자치도       명
# 2308  DT_1IN1603       남자  ...  2017-08-30           Jeju  제주특별자치도       명
# 2309  DT_1IN1603       여자  ...  2017-08-30           Jeju  제주특별자치도       명
#
#               ITM_NM_ENG C2_OBJ_NM_ENG     C2_NM_ENG ORG_ID  \
# 0     Population(Korean)       By age          Total    101
# 1                   Male       By age          Total    101
# 2                 Female       By age          Total    101
# 3              Sex ratio       By age          Total    101
# 4     Population(Korean)       By age   0 to 4 years    101
# ...                  ...           ...           ...    ...
# 2305                Male       By age      Mean ages    101
# 2306              Female       By age      Mean ages    101
# 2307  Population(Korean)       By age    Median ages    101
# 2308                Male       By age    Median ages    101
# 2309              Female       By age    Median ages    101
#
#                     C1_OBJ_NM_ENG C2_OBJ_NM
# 0     By administrative divisions       연령별
# 1     By administrative divisions       연령별
# 2     By administrative divisions       연령별
# 3     By administrative divisions       연령별
# 4     By administrative divisions       연령별
# ...                           ...       ...
# 2305  By administrative divisions       연령별
# 2306  By administrative divisions       연령별
# 2307  By administrative divisions       연령별
# 2308  By administrative divisions       연령별
# 2309  By administrative divisions       연령별
#
# [2310 rows x 22 columns]
