# %%
from dotenv import load_dotenv
import requests
import pandas as pd

apiKey = "ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M"

base_url ="https://kosis.kr/openapi/Param/statisticsParameterData.do"

method="getList"
apiKey="ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M="
itmId="T001+"
objL1="00+11+21+22+23+24+25+26+29+31+32+33+34+35+36+37+38+39+"
objL2="ALL"
objL3=""
objL4=""
objL5=""
objL6=""
objL7=""
objL8=""
format="json"
jsonVD="Y"
prdSe="Y"
newEstPrdCnt="3"
orgId="101"
tblId="DT_1YL20642"

url = f"{base_url}?method=getList&apiKey=ZWRiNzEyMzEwNGI5OWQ3NzcxNGM1MDNiOGJkOTQ0Y2M=&itmId=T001+&objL1=00+11+21+22+23+24+25+26+29+31+32+33+34+35+36+37+38+39+&objL2=ALL&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1YL20642"

response = requests.get(url)

items = response.json()
items
# Out:
# [{'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0',
#   'C2': '11',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0',
#   'C2': '11',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0',
#   'C2': '11',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '전국',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '0',
#   'C2': '12',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '0',
#   'C2': '12',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '0',
#   'C2': '12',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '13644229.5',
#   'C2': '13',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '13338386.5',
#   'C2': '13',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '13084670.5',
#   'C2': '13',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '0',
#   'C2': '21',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '0',
#   'C2': '21',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '0',
#   'C2': '21',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '전국',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '0',
#   'C2': '22',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '0',
#   'C2': '22',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '0',
#   'C2': '22',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '10260357.5',
#   'C2': '23',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '10117020.5',
#   'C2': '23',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '9939238.5',
#   'C2': '23',
#   'C1': '00',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '전국',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '1.1',
#   'C2': '11',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '1',
#   'C2': '11',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0.5',
#   'C2': '11',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '31551',
#   'C2': '12',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '27704',
#   'C2': '12',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '15420',
#   'C2': '12',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '2907178.5',
#   'C2': '13',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '2870340',
#   'C2': '13',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '2833220.5',
#   'C2': '13',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '2.1',
#   'C2': '21',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '1.8',
#   'C2': '21',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '1.3',
#   'C2': '21',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '46198',
#   'C2': '22',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '40049',
#   'C2': '22',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '28010',
#   'C2': '22',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '2227515',
#   'C2': '23',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '2216593',
#   'C2': '23',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '2189893',
#   'C2': '23',
#   'C1': '11',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '서울특별시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-0.7',
#   'C2': '11',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-0.8',
#   'C2': '11',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1',
#   'C2': '11',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-6115',
#   'C2': '12',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-6163',
#   'C2': '12',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-7936',
#   'C2': '12',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '832068',
#   'C2': '13',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '805379.5',
#   'C2': '13',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '781364.5',
#   'C2': '13',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-0.9',
#   'C2': '21',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-0.9',
#   'C2': '21',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.1',
#   'C2': '21',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-5451',
#   'C2': '22',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-5437',
#   'C2': '22',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-6735',
#   'C2': '22',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '629616',
#   'C2': '23',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '614432',
#   'C2': '23',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '596214.5',
#   'C2': '23',
#   'C1': '21',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '부산광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.2',
#   'C2': '11',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.1',
#   'C2': '11',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1',
#   'C2': '11',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-6975',
#   'C2': '12',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-6225',
#   'C2': '12',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-5881',
#   'C2': '12',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '605840.5',
#   'C2': '13',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '591217',
#   'C2': '13',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '576385.5',
#   'C2': '13',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.5',
#   'C2': '21',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.6',
#   'C2': '21',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.5',
#   'C2': '21',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-7172',
#   'C2': '22',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-7274',
#   'C2': '22',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-6523',
#   'C2': '22',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '463263.5',
#   'C2': '23',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '455303',
#   'C2': '23',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '442788',
#   'C2': '23',
#   'C1': '22',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대구광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '1.4',
#   'C2': '11',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '1.6',
#   'C2': '11',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '1.4',
#   'C2': '11',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '11444',
#   'C2': '12',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '13051',
#   'C2': '12',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '10937',
#   'C2': '12',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '811748.5',
#   'C2': '13',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '803832.5',
#   'C2': '13',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '798102.5',
#   'C2': '13',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '1.2',
#   'C2': '21',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '1.3',
#   'C2': '21',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '1.3',
#   'C2': '21',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '7116',
#   'C2': '22',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '7850',
#   'C2': '22',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '7745',
#   'C2': '22',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '608970',
#   'C2': '23',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '606143.5',
#   'C2': '23',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '600389',
#   'C2': '23',
#   'C1': '23',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '인천광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.1',
#   'C2': '11',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.7',
#   'C2': '11',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.6',
#   'C2': '11',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-4279',
#   'C2': '12',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-6387',
#   'C2': '12',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-6005',
#   'C2': '12',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '397099',
#   'C2': '13',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '385132.5',
#   'C2': '13',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '373721',
#   'C2': '13',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.4',
#   'C2': '21',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-2',
#   'C2': '21',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.8',
#   'C2': '21',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-4321',
#   'C2': '22',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-5873',
#   'C2': '22',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-5325',
#   'C2': '22',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '304296.5',
#   'C2': '23',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '298656',
#   'C2': '23',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '291458',
#   'C2': '23',
#   'C1': '24',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '광주광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0.1',
#   'C2': '11',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0.1',
#   'C2': '11',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '0.1',
#   'C2': '11',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '538',
#   'C2': '12',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '528',
#   'C2': '12',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '561',
#   'C2': '12',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '409384',
#   'C2': '13',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '403426.5',
#   'C2': '13',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '398921.5',
#   'C2': '13',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '0.2',
#   'C2': '21',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '0.3',
#   'C2': '21',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '0.3',
#   'C2': '21',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '663',
#   'C2': '22',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '1070',
#   'C2': '22',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '900',
#   'C2': '22',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '315935',
#   'C2': '23',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '313991.5',
#   'C2': '23',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '311159.5',
#   'C2': '23',
#   'C1': '25',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '대전광역시',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.9',
#   'C2': '11',
#   'C1': '26',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '울산광역시',
# ...
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-11718',
#   'C2': '22',
#   'C1': '37',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상북도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-9176',
#   'C2': '22',
#   'C1': '37',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상북도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-8708',
#   'C2': '22',
#   'C1': '37',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상북도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '418684.5',
#   'C2': '23',
#   'C1': '37',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상북도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '402971.5',
#   'C2': '23',
#   'C1': '37',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상북도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '390282.5',
#   'C2': '23',
#   'C1': '37',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상북도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-2.7',
#   'C2': '11',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-2.2',
#   'C2': '11',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.8',
#   'C2': '11',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-20324',
#   'C2': '12',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-16050',
#   'C2': '12',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-12092',
#   'C2': '12',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '752056',
#   'C2': '13',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '716372',
#   'C2': '13',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '688759',
#   'C2': '13',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-3.5',
#   'C2': '21',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-2.9',
#   'C2': '21',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-2.4',
#   'C2': '21',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-19479',
#   'C2': '22',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-15529',
#   'C2': '22',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-12516',
#   'C2': '22',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '551999',
#   'C2': '23',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '531671.5',
#   'C2': '23',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '513430.5',
#   'C2': '23',
#   'C1': '38',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '경상남도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-0.1',
#   'C2': '11',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.2',
#   'C2': '11',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~39세)',
#   'DT': '-1.5',
#   'C2': '11',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-142',
#   'C2': '12',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-1961',
#   'C2': '12',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~39세)',
#   'DT': '-2400',
#   'C2': '12',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '165809.5',
#   'C2': '13',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '160790.5',
#   'C2': '13',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~39세)',
#   'DT': '155570.5',
#   'C2': '13',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1',
#   'C2': '21',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-1.8',
#   'C2': '21',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동률(19~34세)',
#   'DT': '-2.2',
#   'C2': '21',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': '%',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '%',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-1179',
#   'C2': '22',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-2163',
#   'C2': '22',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년순이동(19~34세)',
#   'DT': '-2533',
#   'C2': '22',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '122843',
#   'C2': '23',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2022',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '120612.5',
#   'C2': '23',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2023',
#   'LST_CHN_DE': '2024-10-08',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'},
#  {'C1_OBJ_NM': '행정구역별',
#   'C2_NM': '청년연앙인구(19~34세)',
#   'DT': '117448.5',
#   'C2': '23',
#   'C1': '39',
#   'PRD_SE': 'A',
#   'UNIT_NM_ENG': 'In person',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1YL20642',
#   'ITM_NM': '청년순이동률',
#   'TBL_NM': '청년순이동률(시도/시/군/구)',
#   'PRD_DE': '2024',
#   'LST_CHN_DE': '2025-02-13',
#   'C1_NM': '제주특별자치도',
#   'UNIT_NM': '명',
#   'ORG_ID': '101',
#   'C2_OBJ_NM': '청년순이동률 지표'}]

# %%
df = pd.DataFrame(items)
df.set_index(list(df)[0])


# df.to_csv("./data/청년순이동률.csv")

df
# Out:
#     C1_OBJ_NM           C2_NM        DT  C2  C1 PRD_SE UNIT_NM_ENG ITM_ID  \
# 0       행정구역별  청년순이동률(19~39세)         0  11  00      A           %   T001
# 1       행정구역별  청년순이동률(19~39세)         0  11  00      A           %   T001
# 2       행정구역별  청년순이동률(19~39세)         0  11  00      A           %   T001
# 3       행정구역별   청년순이동(19~39세)         0  12  00      A   In person   T001
# 4       행정구역별   청년순이동(19~39세)         0  12  00      A   In person   T001
# ..        ...             ...       ...  ..  ..    ...         ...    ...
# 319     행정구역별   청년순이동(19~34세)     -2163  22  39      A   In person   T001
# 320     행정구역별   청년순이동(19~34세)     -2533  22  39      A   In person   T001
# 321     행정구역별  청년연앙인구(19~34세)    122843  23  39      A   In person   T001
# 322     행정구역별  청년연앙인구(19~34세)  120612.5  23  39      A   In person   T001
# 323     행정구역별  청년연앙인구(19~34세)  117448.5  23  39      A   In person   T001
#
#           TBL_ID  ITM_NM            TBL_NM PRD_DE  LST_CHN_DE    C1_NM  \
# 0    DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2022  2024-10-08       전국
# 1    DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2023  2024-10-08       전국
# 2    DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2024  2025-02-13       전국
# 3    DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2022  2024-10-08       전국
# 4    DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2023  2024-10-08       전국
# ..           ...     ...               ...    ...         ...      ...
# 319  DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2023  2024-10-08  제주특별자치도
# 320  DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2024  2025-02-13  제주특별자치도
# 321  DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2022  2024-10-08  제주특별자치도
# 322  DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2023  2024-10-08  제주특별자치도
# 323  DT_1YL20642  청년순이동률  청년순이동률(시도/시/군/구)   2024  2025-02-13  제주특별자치도
#
#     UNIT_NM ORG_ID  C2_OBJ_NM
# 0         %    101  청년순이동률 지표
# 1         %    101  청년순이동률 지표
# 2         %    101  청년순이동률 지표
# 3         명    101  청년순이동률 지표
# 4         명    101  청년순이동률 지표
# ..      ...    ...        ...
# 319       명    101  청년순이동률 지표
# 320       명    101  청년순이동률 지표
# 321       명    101  청년순이동률 지표
# 322       명    101  청년순이동률 지표
# 323       명    101  청년순이동률 지표
#
# [324 rows x 17 columns]
