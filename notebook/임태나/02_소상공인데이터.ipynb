# %%
# api 키 불러오기

from dotenv import load_dotenv
load_dotenv()

import os

# %%
base_url = "https://infuser.odcloud.kr/oas/docs?namespace=15083033/v1"

key = os.getenv("Gonggong_API_KEY") # api key 불러오는 것
request_type = "json" #데이터를 주고 받는 형식(딕셔너리 )
service = "tbCycleStationInfo" #요청할 데이터의 이름(대여소 정보)
start_index = 1
end_index = 5

url = f"{base_url}/{key}/{request_type}/{service}/{start_index}/{end_index}"
print(url)
